# %% [markdown]
# <a href="https://colab.research.google.com/github/sushmitamalakar10/LLM/blob/main/behind_the_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from transformers import pipeline, AutoTokenizer,AutoModelForCausalLM

# %%
text = "Hello, this is raw text!"

# %%
model_name = "gpt2"

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
input_ids = tokenizer.encode(text, return_tensors='pt')

# %%
input_ids
# Out:
# tensor([[15496,    11,   428,   318,  8246,  2420,     0]])

# %%
output = model.generate(input_ids, max_length=50, do_sample=True, top_p=0.9)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
output
# Out:
# tensor([[15496,    11,   428,   318,  8246,  2420,     0,   198,   198,  1026,
#           1595,   470,  1560,   345,  1521,   484,  2923,   345,    13,   383,
#           2187,   966,   286,   428,   318,   284,   905,   345,   644,   257,
#            922,  1621,   345,   765,   284,  1560,    13,   198,   198,   464,
#           1621,   345,   765,   284,  1560,   318,   326,   286,   644,  3022]])

# %%
tokenizer.decode(output[0])
# Out:
# "Hello, this is raw text!\n\nIt doesn't tell you why they killed you. The whole point of this is to show you what a good story you want to tell.\n\nThe story you want to tell is that of what happened"
